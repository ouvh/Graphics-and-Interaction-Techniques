# %% [markdown]
# ## Section 4

# %%
# importing the required libraries
import mocaplib  
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 # importing the required libraries
# ----> 2 from mocaplib import ASFReader
#       3 import matplotlib.pyplot as plt
#
# ImportError: cannot import name 'ASFReader' from 'mocaplib' (c:\Users\OussamaLaaroussi\anaconda3\envs\GIT\lib\site-packages\mocaplib\__init__.py)

# %%
# Load the .amc file
amc_file_path = '01_01.amc'
skeleton = ASFReader(asf_path).read()

mocap_data = mocaplib.load_amc(amc_file_path)

# Visualize the motion capture data
# For simplicity, let's plot the trajectory of the root joint (usually the hip)
root_joint = 'root'
x = [frame[root_joint]['tx'] for frame in mocap_data]
y = [frame[root_joint]['ty'] for frame in mocap_data]
z = [frame[root_joint]['tz'] for frame in mocap_data]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(x, y, z)
ax.set_xlabel('X Position')
ax.set_ylabel('Y Position')
ax.set_zlabel('Z Position')
ax.set_title('Trajectory of Root Joint')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Load the .amc file
#       2 amc_file_path = '01_01.amc'
# ----> 3 mocap_data = mocaplib.load_amc(amc_file_path)
#       5 # Visualize the motion capture data
#       6 # For simplicity, let's plot the trajectory of the root joint (usually the hip)
#       7 root_joint = 'root'
#
# AttributeError: module 'mocaplib' has no attribute 'load_amc'
